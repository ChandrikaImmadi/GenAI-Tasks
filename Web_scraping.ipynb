# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandrikaImmadi/GenAI-Tasks/blob/main/Web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

def scrape_news():
    url = "https://www.bbc.com/news"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    headlines = []

    for item in soup.select(".gs-c-promo-heading"):
        text = item.get_text(strip=True)
        if text and len(text) > 20:
            headlines.append(text)

    return headlines[:10]

# %%
def send_email_simulation(headlines):
    print("\n DAILY NEWS EMAIL")
    print("-" * 30)
    for h in headlines:
        print("•", h)

# %%
news = scrape_news()
send_email_simulation(news)
